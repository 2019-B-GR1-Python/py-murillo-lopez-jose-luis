# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
#         ...,
#         [120, 156,  95],
#         [119, 155,  93],
#         [118, 154,  92]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
plt.show()

# %%
plt.imshow(mapache[::-1])
plt.show()

# %%
mapache1, mapache2 = np.split(mapache, 2)

# %%
plt.imshow(mapache1)
plt.show()

# %%
plt.imshow(mapache2)
plt.show()

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
#1. Hacer al mapache azul
blue = np.array((0,0,255))
blue
# Out:
# array([  0,   0, 255])

# %%
blue[None,None,:]
# Out:
# array([[[  0,   0, 255]]])

# %%
mapache_azul = mapache + blue[None,None,:]
mapache_azul = mapache_azul / 510
mapache_azul
# Out:
# array([[[0.2372549 , 0.21960784, 0.75686275],
#         [0.27058824, 0.25294118, 0.79019608],
#         [0.3       , 0.28235294, 0.82352941],
#         ...,
#         [0.23333333, 0.24705882, 0.64509804],
#         [0.25686275, 0.26666667, 0.66078431],
#         [0.27254902, 0.28235294, 0.67647059]],
#
#        [[0.1745098 , 0.16078431, 0.69607843],
#         [0.21568627, 0.20196078, 0.7372549 ],
#         [0.25490196, 0.23921569, 0.78039216],
#         ...,
#         [0.23137255, 0.24509804, 0.63921569],
#         [0.2627451 , 0.27647059, 0.67058824],
#         [0.28627451, 0.3       , 0.69411765]],
#
#        [[0.14313725, 0.12941176, 0.66470588],
#         [0.18431373, 0.17058824, 0.70588235],
#         [0.2254902 , 0.21176471, 0.74705882],
#         ...,
#         [0.22941176, 0.24705882, 0.63921569],
#         [0.26078431, 0.27843137, 0.67058824],
#         [0.28235294, 0.3       , 0.69215686]],
#
#        ...,
#
#        [[0.17058824, 0.20784314, 0.64901961],
#         [0.18431373, 0.21568627, 0.65882353],
#         [0.20980392, 0.24313725, 0.68039216],
#         ...,
#         [0.23529412, 0.30980392, 0.69019608],
#         [0.23333333, 0.30784314, 0.68823529],
#         [0.23333333, 0.30980392, 0.68627451]],
#
#        [[0.16666667, 0.19803922, 0.64117647],
#         [0.18627451, 0.21764706, 0.66078431],
#         [0.21960784, 0.24901961, 0.68823529],
#         ...,
#         [0.2372549 , 0.30784314, 0.68823529],
#         [0.23529412, 0.30588235, 0.68431373],
#         [0.23529412, 0.30588235, 0.68431373]],
#
#        [[0.16666667, 0.19803922, 0.64509804],
#         [0.19019608, 0.22156863, 0.66470588],
#         [0.21764706, 0.24705882, 0.69019608],
#         ...,
#         [0.23529412, 0.30588235, 0.68627451],
#         [0.23333333, 0.30392157, 0.68235294],
#         [0.23137255, 0.30196078, 0.68039216]]])

# %%
plt.imshow(mapache_azul)
plt.show()

# %%
#Alterar el espacio-tiempo en el mapache (rompecabezas)
arreglo_random = np.arange(8)
np.random.shuffle(arreglo_random)
arreglo_random
# Out:
# array([4, 1, 0, 2, 6, 5, 7, 3])

# %%
mapache_rp_1 = np.hsplit(mapache1,4)
mapache_rp_2 = np.hsplit(mapache2,4)
mapache_rp = np.array(mapache_rp_1 + mapache_rp_2)
mapache_rp
# Out:
# array([[[[121, 112, 131],
#          [138, 129, 148],
#          [153, 144, 165],
#          ...,
#          [ 67,  65,  79],
#          [ 90,  88, 102],
#          [117, 115, 129]],
#
#         [[ 89,  82, 100],
#          [110, 103, 121],
#          [130, 122, 143],
#          ...,
#          [ 67,  65,  79],
#          [ 67,  65,  79],
#          [ 73,  71,  85]],
#
#         [[ 73,  66,  84],
#          [ 94,  87, 105],
#          [115, 108, 126],
#          ...,
#          [ 83,  81,  95],
#          [ 62,  60,  74],
#          [ 51,  49,  63]],
#
#         ...,
#
#         [[203, 233, 111],
#          [198, 228, 106],
#          [191, 223,  98],
#          ...,
#          [134, 129, 151],
#          [169, 164, 187],
#          [195, 190, 213]],
#
#         [[203, 233, 109],
#          [198, 228, 104],
#          [191, 223,  96],
#          ...,
#          [119, 114, 136],
#          [143, 138, 161],
#          [170, 165, 188]],
#
#         [[195, 225, 101],
#          [194, 226,  99],
#          [193, 225,  98],
#          ...,
#          [103,  98, 120],
#          [115, 110, 133],
#          [140, 135, 158]]],
#
#
#        [[[149, 138, 154],
#          [153, 145, 160],
#          [165, 157, 170],
#          ...,
#          [158, 144, 144],
#          [158, 144, 144],
#          [151, 137, 137]],
#
#         [[ 93,  82,  98],
#          [117, 109, 124],
#          [155, 147, 160],
#          ...,
#          [159, 145, 145],
#          [159, 145, 145],
#          [149, 135, 135]],
#
#         [[ 55,  44,  60],
#          [ 80,  72,  87],
#          [117, 109, 122],
#          ...,
#          [168, 154, 154],
#          [171, 157, 157],
#          [160, 146, 146]],
#
#         ...,
#
#         [[193, 188, 210],
#          [183, 178, 200],
#          [164, 159, 181],
#          ...,
#          [ 84,  86,  99],
#          [ 85,  87, 100],
#          [ 89,  91, 104]],
#
#         [[180, 175, 197],
#          [170, 165, 187],
#          [156, 151, 173],
#          ...,
#          [ 65,  67,  82],
#          [ 70,  72,  87],
#          [ 79,  81,  94]],
#
#         [[168, 163, 185],
#          [160, 155, 177],
#          [157, 149, 172],
#          ...,
#          [ 82,  84,  99],
#          [ 87,  89, 104],
#          [ 95,  97, 112]]],
#
#
#        [[[111, 102, 103],
#          [112, 103, 104],
#          [126, 117, 118],
#          ...,
#          [ 65,  66,  84],
#          [ 67,  68,  86],
#          [ 69,  70,  88]],
#
#         [[111, 101, 102],
#          [107,  97,  98],
#          [116, 106, 107],
#          ...,
#          [ 67,  68,  88],
#          [ 68,  69,  89],
#          [ 69,  70,  90]],
#
#         [[116, 106, 107],
#          [110, 100, 101],
#          [117, 107, 108],
#          ...,
#          [ 70,  71,  91],
#          [ 69,  70,  90],
#          [ 68,  69,  89]],
#
#         ...,
#
#         [[ 98,  94, 109],
#          [100,  96, 111],
#          [103,  99, 114],
#          ...,
#          [ 42,  46,  49],
#          [ 32,  36,  39],
#          [ 28,  32,  35]],
#
#         [[ 94,  88, 102],
#          [ 89,  85,  99],
#          [ 88,  84,  98],
#          ...,
#          [ 23,  27,  30],
#          [ 29,  33,  36],
#          [ 35,  39,  42]],
#
#         [[119, 113, 127],
#          [120, 114, 128],
#          [121, 117, 131],
#          ...,
#          [ 40,  44,  47],
#          [ 40,  44,  47],
#          [ 37,  41,  44]]],
#
#
#        ...,
#
#
#        [[[163, 159, 176],
#          [170, 166, 183],
#          [169, 165, 182],
#          ...,
#          [124, 127, 146],
#          [113, 116, 133],
#          [107, 110, 127]],
#
#         [[159, 155, 172],
#          [167, 163, 180],
#          [167, 163, 180],
#          ...,
#          [172, 175, 192],
#          [163, 166, 181],
#          [158, 161, 176]],
#
#         [[157, 153, 170],
#          [167, 163, 180],
#          [168, 163, 183],
#          ...,
#          [187, 190, 205],
#          [191, 195, 207],
#          [193, 197, 209]],
#
#         ...,
#
#         [[ 16,  23,   5],
#          [ 17,  24,   6],
#          [ 18,  25,   9],
#          ...,
#          [ 93, 132,  77],
#          [ 93, 132,  77],
#          [ 93, 132,  77]],
#
#         [[ 17,  24,   6],
#          [ 17,  24,   6],
#          [ 17,  24,   8],
#          ...,
#          [ 95, 134,  79],
#          [ 94, 133,  78],
#          [ 94, 133,  78]],
#
#         [[ 17,  24,   6],
#          [ 17,  24,   8],
#          [ 17,  24,   8],
#          ...,
#          [ 96, 135,  80],
#          [ 96, 135,  80],
#          [ 96, 135,  80]]],
#
#
#        [[[103,  99, 114],
#          [106, 104, 118],
#          [114, 112, 126],
#          ...,
#          [ 40,  37,  44],
#          [ 36,  33,  40],
#          [ 33,  30,  37]],
#
#         [[116, 113, 130],
#          [100,  97, 114],
#          [ 84,  81,  98],
#          ...,
#          [ 36,  33,  40],
#          [ 35,  32,  39],
#          [ 35,  32,  39]],
#
#         [[162, 159, 178],
#          [167, 164, 183],
#          [155, 152, 171],
#          ...,
#          [ 38,  35,  42],
#          [ 40,  37,  44],
#          [ 41,  38,  45]],
#
#         ...,
#
#         [[ 91, 134,  81],
#          [ 94, 134,  81],
#          [ 92, 131,  74],
#          ...,
#          [ 14,  15,  10],
#          [ 14,  15,  10],
#          [ 14,  15,  10]],
#
#         [[ 90, 133,  80],
#          [ 93, 133,  80],
#          [ 92, 131,  74],
#          ...,
#          [ 18,  19,  14],
#          [ 18,  19,  14],
#          [ 19,  20,  15]],
#
#         [[ 89, 132,  79],
#          [ 92, 132,  79],
#          [ 92, 131,  74],
#          ...,
#          [ 23,  24,  19],
#          [ 23,  24,  19],
#          [ 23,  24,  19]]],
#
#
#        [[[ 37,  36,  44],
#          [ 40,  39,  47],
#          [ 43,  42,  50],
#          ...,
#          [ 28,  37,  20],
#          [ 29,  38,  21],
#          [ 29,  38,  21]],
#
#         [[ 35,  34,  42],
#          [ 36,  35,  43],
#          [ 37,  36,  44],
#          ...,
#          [ 26,  35,  18],
#          [ 27,  36,  19],
#          [ 27,  36,  19]],
#
#         [[ 47,  46,  54],
#          [ 43,  42,  50],
#          [ 35,  34,  42],
#          ...,
#          [ 26,  35,  18],
#          [ 27,  36,  19],
#          [ 27,  36,  19]],
#
#         ...,
#
#         [[ 25,  19,  21],
#          [ 24,  18,  18],
#          [ 26,  21,  18],
#          ...,
#          [120, 158,  97],
#          [119, 157,  96],
#          [119, 158,  95]],
#
#         [[ 30,  24,  26],
#          [ 28,  19,  20],
#          [ 36,  28,  25],
#          ...,
#          [121, 157,  96],
#          [120, 156,  94],
#          [120, 156,  94]],
#
#         [[ 36,  30,  30],
#          [ 31,  23,  21],
#          [ 43,  35,  32],
#          ...,
#          [120, 156,  95],
#          [119, 155,  93],
#          [118, 154,  92]]]], dtype=uint8)

# %%
np.random.shuffle(mapache_rp)

# %%
mapache_alterado_1 = mapache_rp[0]
for i in range(1,4):
    mapache_alterado_1 = np.concatenate((mapache_alterado_1, mapache_rp[i]),1)
mapache_alterado_2 = mapache_rp[4]
for i in range(5,8):
    mapache_alterado_2 = np.concatenate((mapache_alterado_2, mapache_rp[i]),1)
mapache_alterado_2.shape
mapache_alterado = np.concatenate((mapache_alterado_1, mapache_alterado_2), 0)

# %%
plt.imshow(mapache_alterado)
plt.show()
